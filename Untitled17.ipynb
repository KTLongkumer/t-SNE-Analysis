# %%
import pandas as pd

# Load the dataset from the uploaded file
file_path = 'Brain_GSE50161.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataset
data.head()
# Out:
#    samples        type  1007_s_at   1053_at     117_at    121_at  1255_g_at  \
# 0      834  ependymoma  12.498150  7.604868   6.880934  9.027128   4.176175
# 1      835  ependymoma  13.067436  7.998090   7.209076  9.723322   4.826126
# 2      836  ependymoma  13.068179  8.573674   8.647684  9.613002   4.396581
# 3      837  ependymoma  12.456040  9.098977   6.628784  8.517677   4.154847
# 4      838  ependymoma  12.699958  8.800721  11.556188  9.166309   4.165891
#
#     1294_at   1316_at   1320_at  ...  AFFX-r2-Ec-bioD-3_at  \
# 0  7.224920  6.085942  6.835999  ...              9.979005
# 1  7.539381  6.250962  8.012549  ...             11.924749
# 2  7.813101  6.007746  7.178156  ...             12.154405
# 3  8.361843  6.596064  6.347285  ...             11.969072
# 4  7.923826  6.212754  6.866387  ...             11.411701
#
#    AFFX-r2-Ec-bioD-5_at  AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at  \
# 0              9.926470            12.719785            12.777792
# ...

# %%
import pandas as pd

# Load the dataset from the uploaded file
file_path = 'Brain_GSE50161.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataset
print(data.head())
# Out:
#    samples        type  1007_s_at   1053_at     117_at    121_at  1255_g_at  \
# 0      834  ependymoma  12.498150  7.604868   6.880934  9.027128   4.176175
# 1      835  ependymoma  13.067436  7.998090   7.209076  9.723322   4.826126
# 2      836  ependymoma  13.068179  8.573674   8.647684  9.613002   4.396581
# 3      837  ependymoma  12.456040  9.098977   6.628784  8.517677   4.154847
# 4      838  ependymoma  12.699958  8.800721  11.556188  9.166309   4.165891
#
#     1294_at   1316_at   1320_at  ...  AFFX-r2-Ec-bioD-3_at  \
# 0  7.224920  6.085942  6.835999  ...              9.979005
# 1  7.539381  6.250962  8.012549  ...             11.924749
# 2  7.813101  6.007746  7.178156  ...             12.154405
# 3  8.361843  6.596064  6.347285  ...             11.969072
# 4  7.923826  6.212754  6.866387  ...             11.411701
#
#    AFFX-r2-Ec-bioD-5_at  AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at  \
# 0              9.926470            12.719785            12.777792
# ...

# %%
import pandas as pd
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# Load the dataset from the uploaded file
file_path = 'Brain_GSE50161.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataset
print(data.head())

# Data preprocessing
# Handle missing values
data.fillna(data.mean(), inplace=True)

# One-hot encoding for categorical variables (if any)
data = pd.get_dummies(data, drop_first=True)

# Normalization/Standardization
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# Initialize and fit t-SNE
tsne = TSNE(n_components=2, perplexity=30, learning_rate=200, n_iter=1000, random_state=42)
reduced_data = tsne.fit_transform(scaled_data)

# Plotting the t-SNE results
plt.figure(figsize=(10, 7))
plt.scatter(reduced_data[:, 0], reduced_data[:, 1], c=None)  # Replace 'None' with your labels if you have any
plt.colorbar()
plt.title('t-SNE Visualization')
plt.show()
# Out:
# /Users/ktlkr/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
#    samples        type  1007_s_at   1053_at     117_at    121_at  1255_g_at  \
# 0      834  ependymoma  12.498150  7.604868   6.880934  9.027128   4.176175
# 1      835  ependymoma  13.067436  7.998090   7.209076  9.723322   4.826126
# 2      836  ependymoma  13.068179  8.573674   8.647684  9.613002   4.396581
# 3      837  ependymoma  12.456040  9.098977   6.628784  8.517677   4.154847
# 4      838  ependymoma  12.699958  8.800721  11.556188  9.166309   4.165891
#
#     1294_at   1316_at   1320_at  ...  AFFX-r2-Ec-bioD-3_at  \
# 0  7.224920  6.085942  6.835999  ...              9.979005
# 1  7.539381  6.250962  8.012549  ...             11.924749
# 2  7.813101  6.007746  7.178156  ...             12.154405
# ...

# %%
import pandas as pd
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# Path to the uploaded dataset
file_path = 'Brain_GSE50161.csv'

# Load your dataset
data = pd.read_csv(file_path)

# Display the first few rows of the dataset to understand its structure
print(data.head())

# Data preprocessing
# Handle missing values (if any)
data.fillna(data.mean(), inplace=True)

# One-hot encoding for categorical variables (if any)
data = pd.get_dummies(data, drop_first=True)

# Normalization/Standardization
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# Initialize and fit t-SNE
tsne = TSNE(n_components=2, perplexity=30, learning_rate=200, n_iter=1000, random_state=42)
reduced_data = tsne.fit_transform(scaled_data)

# Plotting the t-SNE results
plt.figure(figsize=(10, 7))
plt.scatter(reduced_data[:, 0], reduced_data[:, 1])
plt.colorbar()
plt.title('t-SNE Visualization')
plt.xlabel('t-SNE 1')
plt.ylabel('t-SNE 2')
plt.show()
# Out:
#    samples        type  1007_s_at   1053_at     117_at    121_at  1255_g_at  \
# 0      834  ependymoma  12.498150  7.604868   6.880934  9.027128   4.176175
# 1      835  ependymoma  13.067436  7.998090   7.209076  9.723322   4.826126
# 2      836  ependymoma  13.068179  8.573674   8.647684  9.613002   4.396581
# 3      837  ependymoma  12.456040  9.098977   6.628784  8.517677   4.154847
# 4      838  ependymoma  12.699958  8.800721  11.556188  9.166309   4.165891
#
#     1294_at   1316_at   1320_at  ...  AFFX-r2-Ec-bioD-3_at  \
# 0  7.224920  6.085942  6.835999  ...              9.979005
# 1  7.539381  6.250962  8.012549  ...             11.924749
# 2  7.813101  6.007746  7.178156  ...             12.154405
# 3  8.361843  6.596064  6.347285  ...             11.969072
# 4  7.923826  6.212754  6.866387  ...             11.411701
#
#    AFFX-r2-Ec-bioD-5_at  AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at  \
# 0              9.926470            12.719785            12.777792
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE

# %%
file_path = 'Brain_GSE50161.csv'
data = pd.read_csv(file_path)

# %%
# Check for missing values
print(data.isnull().sum())

# Fill missing values with the mean or any appropriate method
data = data.fillna(data.mean())
# Out:
# samples            0
# type               0
# 1007_s_at          0
# 1053_at            0
# 117_at             0
#                   ..
# AFFX-ThrX-5_at     0
# AFFX-ThrX-M_at     0
# AFFX-TrpnX-3_at    0
# AFFX-TrpnX-5_at    0
# AFFX-TrpnX-M_at    0
# Length: 54677, dtype: int64
# /var/folders/y_/4_ck1m5x1fx0g48d_82vflrc0000gn/T/ipykernel_86424/241509647.py:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data = data.fillna(data.mean())

# %%
# Identify categorical columns
categorical_cols = data.select_dtypes(include=['object']).columns

# One-hot encode categorical variables
data = pd.get_dummies(data, columns=categorical_cols)

# %%
# Standardize the data
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)

# %%
# Initialize t-SNE
tsne = TSNE(n_components=2, random_state=42)

# Fit and transform the data
data_tsne = tsne.fit_transform(data_scaled)

# Create a DataFrame with t-SNE results
tsne_df = pd.DataFrame(data_tsne, columns=['TSNE1', 'TSNE2'])

# Plot the results
plt.figure(figsize=(10, 8))
plt.scatter(tsne_df['TSNE1'], tsne_df['TSNE2'])
plt.xlabel('TSNE1')
plt.ylabel('TSNE2')
plt.title('t-SNE Results')
plt.show()
# Out:
# /Users/ktlkr/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/ktlkr/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE

# %%
file_path = 'Brain_GSE50161.csv'
data = pd.read_csv(file_path)

# %%
# Handle missing values
data = data.fillna(data.mean())

# Encode categorical variables
categorical_cols = data.select_dtypes(include=['object']).columns
data = pd.get_dummies(data, columns=categorical_cols)

# Standardize the data
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)
# Out:
# /var/folders/y_/4_ck1m5x1fx0g48d_82vflrc0000gn/T/ipykernel_86424/1166217826.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data = data.fillna(data.mean())

# %%
def plot_tsne(perplexity, learning_rate):
    tsne = TSNE(n_components=2, perplexity=perplexity, learning_rate=learning_rate, random_state=42)
    data_tsne = tsne.fit_transform(data_scaled)
    tsne_df = pd.DataFrame(data_tsne, columns=['TSNE1', 'TSNE2'])
    
    plt.figure(figsize=(10, 8))
    plt.scatter(tsne_df['TSNE1'], tsne_df['TSNE2'])
    plt.title(f't-SNE with Perplexity={perplexity}, Learning Rate={learning_rate}')
    plt.xlabel('TSNE1')
    plt.ylabel('TSNE2')
    plt.show()

# Example: Try different values of perplexity and learning rate
for perplexity in [5, 30, 50]:
    for learning_rate in [10, 100, 200]:
        plot_tsne(perplexity, learning_rate)
# Out:
# /Users/ktlkr/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/ktlkr/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/ktlkr/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/ktlkr/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/ktlkr/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
# ...

# %%
from sklearn.manifold import TSNE

# Initialize t-SNE model
tsne = TSNE(
    n_components=2,          # Output dimensions (2 for 2D visualization)
    perplexity=30,           # Balance between local and global aspects
    learning_rate=200,       # Learning rate for optimization
    n_iter=1000,             # Number of iterations
    random_state=42          # Seed for reproducibility
)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/y_/4_ck1m5x1fx0g48d_82vflrc0000gn/T/ipykernel_86424/1238098041.py in <module>
#       8
#       9 # Separate features and target if needed
# ---> 10 X = data.drop(columns=['target_column'])  # Adjust based on your dataset
#      11 y = data['target_column']  # Target labels if you need them
#      12
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4952                 weight  1.0     0.8
#    4953         """
# -> 4954         return super().drop(
# ...

# %%
print(data.columns)
# Out:
# Index(['samples', 'type', '1007_s_at', '1053_at', '117_at', '121_at',
#        '1255_g_at', '1294_at', '1316_at', '1320_at',
#        ...
#        'AFFX-r2-Ec-bioD-3_at', 'AFFX-r2-Ec-bioD-5_at', 'AFFX-r2-P1-cre-3_at',
#        'AFFX-r2-P1-cre-5_at', 'AFFX-ThrX-3_at', 'AFFX-ThrX-5_at',
#        'AFFX-ThrX-M_at', 'AFFX-TrpnX-3_at', 'AFFX-TrpnX-5_at',
#        'AFFX-TrpnX-M_at'],
#       dtype='object', length=54677)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/y_/4_ck1m5x1fx0g48d_82vflrc0000gn/T/ipykernel_86424/244020454.py in <module>
#       1 # Separate features and target based on the actual column names
# ----> 2 X = data.drop(columns=['label'])  # Replace 'label' with your actual target column name
#       3 y = data['label']  # Replace 'label' with your actual target column name
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4952                 weight  1.0     0.8
#    4953         """
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/y_/4_ck1m5x1fx0g48d_82vflrc0000gn/T/ipykernel_86424/780279508.py in <module>
#       6 # One-hot encode categorical features
#       7 encoder = OneHotEncoder(sparse=False)
# ----> 8 X_encoded = encoder.fit_transform(data[categorical_columns])
#       9
#      10 # Drop categorical columns and concatenate encoded features
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Load your data
data = pd.read_csv('Brain_GSE50161.csv')

# Print column names to verify
print(data.columns)

# Separate features and target
X = data.drop(columns=['samples', 'type'])  # Drop non-feature columns
y = data['type']  # Target labels

# Preprocess the features (e.g., standardize)
scaler = StandardScaler()
X_preprocessed = scaler.fit_transform(X)

# Initialize t-SNE model
tsne = TSNE(
    n_components=2,
    perplexity=30,
    learning_rate=200,
    n_iter=1000,
    random_state=42
)

# Train the t-SNE model
X_tsne = tsne.fit_transform(X_preprocessed)

# Plot the t-SNE result
plt.figure(figsize=(10, 7))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap='viridis')
plt.colorbar()  # Show color bar to identify classes
plt.title('t-SNE Visualization')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.show()
# Out:
# Index(['samples', 'type', '1007_s_at', '1053_at', '117_at', '121_at',
#        '1255_g_at', '1294_at', '1316_at', '1320_at',
#        ...
#        'AFFX-r2-Ec-bioD-3_at', 'AFFX-r2-Ec-bioD-5_at', 'AFFX-r2-P1-cre-3_at',
#        'AFFX-r2-P1-cre-5_at', 'AFFX-ThrX-3_at', 'AFFX-ThrX-5_at',
#        'AFFX-ThrX-M_at', 'AFFX-TrpnX-3_at', 'AFFX-TrpnX-5_at',
#        'AFFX-TrpnX-M_at'],
#       dtype='object', length=54677)
# /Users/ktlkr/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the target labels
y_encoded = label_encoder.fit_transform(y)

# Check the mapping of labels to numbers
label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print("Label mapping:", label_mapping)
# Out:
# Label mapping: {'ependymoma': 0, 'glioblastoma': 1, 'medulloblastoma': 2, 'normal': 3, 'pilocytic_astrocytoma': 4}

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Load your data
data = pd.read_csv('Brain_GSE50161.csv')

# Separate features and target
X = data.drop(columns=['samples', 'type'])
y = data['type']

# Preprocess the features (e.g., standardize)
scaler = StandardScaler()
X_preprocessed = scaler.fit_transform(X)

# Encode target labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Initialize t-SNE model
tsne = TSNE(
    n_components=2,
    perplexity=30,
    learning_rate=200,
    n_iter=1000,
    random_state=42
)

# Train the t-SNE model
X_tsne = tsne.fit_transform(X_preprocessed)

# Plot the t-SNE result
plt.figure(figsize=(10, 7))
scatter = plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y_encoded, cmap='viridis')
plt.colorbar(scatter, ticks=range(len(label_encoder.classes_)), format=plt.FuncFormatter(lambda x, pos: label_encoder.classes_[int(x)]))
plt.title('t-SNE Visualization')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.show()
# Out:
# /Users/ktlkr/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt

# Plot the t-SNE result
plt.figure(figsize=(10, 7))
scatter = plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y_encoded, cmap='viridis', alpha=0.7)
plt.colorbar(scatter, ticks=range(len(label_encoder.classes_)), format=plt.FuncFormatter(lambda x, pos: label_encoder.classes_[int(x)]))
plt.title('t-SNE Visualization')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.show()

# %%
import seaborn as sns

# Create a DataFrame for easier plotting with seaborn
tsne_df = pd.DataFrame({
    'Dimension 1': X_tsne[:, 0],
    'Dimension 2': X_tsne[:, 1],
    'Label': y
})

# Plot using seaborn
plt.figure(figsize=(12, 8))
sns.scatterplot(data=tsne_df, x='Dimension 1', y='Dimension 2', hue='Label', palette='viridis', alpha=0.7, s=100)
plt.title('t-SNE Visualization with Seaborn')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.legend(title='Label')
plt.show()

# %%
from sklearn.manifold import TSNE
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import pairwise_distances
import numpy as np

# Define a grid of hyperparameters
perplexities = [5, 30, 50]
learning_rates = [10, 200, 1000]
n_iter = [500, 1000, 1500]

best_score = float('inf')
best_params = {}

# Grid search
for perplexity in perplexities:
    for learning_rate in learning_rates:
        for n_iter_ in n_iter:
            tsne = TSNE(
                n_components=2,
                perplexity=perplexity,
                learning_rate=learning_rate,
                n_iter=n_iter_,
                random_state=42
            )
            
            # Fit and transform
            X_tsne = tsne.fit_transform(X_preprocessed)
            
            # Evaluate clustering (using a metric like pairwise distances)
            # Calculate mean pairwise distance between points in the reduced space
            mean_dist = np.mean(pairwise_distances(X_tsne))
            
            # Update the best score and parameters
            if mean_dist < best_score:
                best_score = mean_dist
                best_params = {'perplexity': perplexity, 'learning_rate': learning_rate, 'n_iter': n_iter_}

print("Best Parameters:", best_params)
print("Best Score (Mean Pairwise Distance):", best_score)
# Out:
# /Users/ktlkr/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/ktlkr/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/ktlkr/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/ktlkr/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/ktlkr/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
# ...

# %%
from sklearn.manifold import TSNE
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import pairwise_distances
import numpy as np
import random

# Define ranges for hyperparameters
perplexities = [5, 30, 50]
learning_rates = [10, 200, 1000]
n_iter = [500, 1000, 1500]

# Random search
best_score = float('inf')
best_params = {}

for _ in range(10):  # Number of random samples
    perplexity = random.choice(perplexities)
    learning_rate = random.choice(learning_rates)
    n_iter_ = random.choice(n_iter)
    
    tsne = TSNE(
        n_components=2,
        perplexity=perplexity,
        learning_rate=learning_rate,
        n_iter=n_iter_,
        random_state=42
    )
    
    # Fit and transform
    X_tsne = tsne.fit_transform(X_preprocessed)
    
    # Evaluate clustering
    mean_dist = np.mean(pairwise_distances(X_tsne))
    
    # Update the best score and parameters
    if mean_dist < best_score:
        best_score = mean_dist
        best_params = {'perplexity': perplexity, 'learning_rate': learning_rate, 'n_iter': n_iter_}

print("Best Parameters:", best_params)
print("Best Score (Mean Pairwise Distance):", best_score)
# Out:
# /Users/ktlkr/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/ktlkr/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/ktlkr/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/ktlkr/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/ktlkr/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
# ...

# %%
from sklearn.metrics import silhouette_score

# Assuming y_encoded is the encoded ground truth labels
silhouette_avg = silhouette_score(X_tsne, y_encoded)
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Silhouette Score: -0.10883580148220062
